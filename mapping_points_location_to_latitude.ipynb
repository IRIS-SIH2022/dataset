# %%
import pandas as pd
import numpy as np

# %%
file_path = "/Users/anshitbansal/Documents/hotspot-prediction/Delhi/CREATED DATASET.csv"

# %%
df = pd.read_csv(file_path)

# %%
df['Longitude'].min()
# Out:
# -87.91703396

# %%
df['Longitude'].max()
# Out:
# -87.52463966

# %%
df['Latitude'].min()
# Out:
# 41.64460772

# %%
df['Latitude'].max()
# Out:
# 42.02254877

# %%
south_west_delhi_logitude = 77.0346 
difference_logitude_min = south_west_delhi_logitude - df['Longitude'].min()
difference_logitude_min
# Out:
# 164.95163395999998

# %%
df['Longitude'] = df['Longitude'] + difference_logitude_min

# %%
# Logitude has been moved

# %%
from shapely.geometry import Point 
import geopandas as gpd 
from geopandas import GeoDataFrame

# %%
# geometry = [Point (xy) for xy in zip(df['Longitude'], df['Latitude'])]
# gdf = GeoDataFrame (df, geometry=geometry)
# #this is a simple map that goes with geopandas
# world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# gdf.plot(ax=world.plot(figsize=(15, 15)), marker='o', color='red', markersize=15)

# %%
# Now to move Latitude

# %%
df['Latitude'].max()
# Out:
# 42.02254877

# %%
north_delhi_latitude = 28.7886
difference_latitude = north_delhi_latitude - df['Latitude'].max()
difference_latitude
# Out:
# -13.233948770000001

# %%
df['Latitude'] = df['Latitude'] + difference_latitude

# %%
geometry = [Point (xy) for xy in zip(df['Longitude'], df['Latitude'])]
gdf = GeoDataFrame (df, geometry=geometry)
#this is a simple map that goes with geopandas
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gdf.plot(ax=world.plot(figsize=(15, 15)), marker='o', color='red', markersize=15)
# Out:
# <AxesSubplot:>

# %%
## Now checking if all coordinates are in Delhi

# %%
import geopy

# %%
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

geolocator = Nominatim(user_agent = 'sih')

# %%
reverse = RateLimiter(geolocator.reverse, min_delay_seconds=1)

for lat, long in zip(df['Latitude'], df['Longitude']):
    location = reverse((lat, long), language='en', exactly_one=True)
    try:
        print(location.raw)
    except:
        None
    try:
        print(location.raw)
    except:
        None
# Out:
# {'place_id': 297963048, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 3778306, 'lat': '28.377893200000003', 'lon': '77.13813346572329', 'display_name': 'Asola, Sohna, Gurugram, Haryana, India', 'address': {'suburb': 'Asola', 'city_district': 'Sohna', 'city': 'Gurugram', 'state': 'Haryana', 'ISO3166-2-lvl4': 'IN-HR', 'country': 'India', 'country_code': 'in'}, 'boundingbox': ['28.2671474', '28.4886106', '77.0961713', '77.2905477']}
# ...

# %%
# Here I have stopped the code that is why error

# %%
df.to_csv("Delhi_Crime_Dataset.csv")

# %%
df.columns

# %%
type(str(df['Latitude'][0]))

# %% [markdown]
# ## If we were given Locations

# %%
# Here store all locations from which you want to generate coordinates 
locations = ["India Gate Delhi", "Shiv Nadar University Dadri"] * 10000

# %%
from geopy.extra.rate_limiter import RateLimiter
geocode = RateLimiter(geolocator.geocode, min_delay_seconds = 0, return_value_on_exception = None)

# %%
for location in locations:
    lat_long = geolocator.geocode(location)
    print(lat_long)
    
#     print("Latitude is : ", lat_long.latitude)
#     print("Longitude is : " , lat_long.longitude)
    print("\n")
# Out:
# India Gate, Shahjahan Road, Pandara Park, Chanakya Puri Tehsil, New Delhi, Delhi, 020626, India
#
#
# Shiv Nadar University, NH34;NH334C, Dadri, Gautam Buddha Nagar, Uttar Pradesh, 201314, India
#
#
# India Gate, Shahjahan Road, Pandara Park, Chanakya Puri Tehsil, New Delhi, Delhi, 020626, India
#
#
# Shiv Nadar University, NH34;NH334C, Dadri, Gautam Buddha Nagar, Uttar Pradesh, 201314, India
#
#
# India Gate, Shahjahan Road, Pandara Park, Chanakya Puri Tehsil, New Delhi, Delhi, 020626, India
#
#
# Shiv Nadar University, NH34;NH334C, Dadri, Gautam Buddha Nagar, Uttar Pradesh, 201314, India
#
#
# India Gate, Shahjahan Road, Pandara Park, Chanakya Puri Tehsil, New Delhi, Delhi, 020626, India
#
#
# Shiv Nadar University, NH34;NH334C, Dadri, Gautam Buddha Nagar, Uttar Pradesh, 201314, India
#
#
# India Gate, Shahjahan Road, Pandara Park, Chanakya Puri Tehsil, New Delhi, Delhi, 020626, India
#
#
# ...
